# %%
import tensorflow as tf
import pandas as pd

data = pd.read_csv('processed_data.csv')
data.head()
# Out:
#      0    1    2    3  label_0  label_1  label_2
# 0  516  847  786  354        1        0        0
# 1  572  791  786  214        1        0        0
# 2  624  770  768  221        1        0        0
# 3  651  750  786  227        1        0        0
# 4  668  689  768  255        1        0        0

# %%
# Import necessary libraries
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.initializers import RandomNormal, RandomUniform
from tensorflow.keras.initializers import GlorotNormal, GlorotUniform

# Load standardized data
data = pd.read_csv('processed_data.csv')
X = data[['0', '1', '2', '3']].values
y = data[['label_0', 'label_1', 'label_2']].values

# %%
from tensorflow.keras.models import Model


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=30)

# Define the neural network model using Keras
model = Sequential()


# Input Layer and Hidden Layer 1
model.add(Dense(6, input_dim=4, activation='relu'))

# Hidden Layer 2
model.add(Dense(5, activation='relu' ))

# Output Layer
model.add(Dense(3, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])



# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=10, validation_data=(X_test, y_test), verbose=1)

# Evaluate the model
train_loss, train_accuracy = model.evaluate(X_train, y_train, verbose=1)
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)


print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

for layer_num, layer in enumerate(model.layers):
    weights = layer.get_weights()[0]
    biases = layer.get_weights()[1]
    
    print(f"Layer {layer_num + 1} - Weights:\n {weights}\n")
    print(f"Layer {layer_num + 1} - Biases:\n {biases}\n")
    
intermediate_layer_model = Model(inputs=model.input, outputs=model.get_layer(index=2).output)
input_data = tf.constant([[318,974,875,46]]) # Örnek girdi verisi
intermediate_output = intermediate_layer_model.predict(input_data)
print(intermediate_output)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1s 6ms/step - loss: 65.5895 - accuracy: 0.3217 - val_loss: 52.3112 - val_accuracy: 0.4000
# Epoch 2/50
# 23/23 [==============================] - 0s 3ms/step - loss: 48.4517 - accuracy: 0.3913 - val_loss: 38.0296 - val_accuracy: 0.4913
# Epoch 3/50
# 23/23 [==============================] - 0s 2ms/step - loss: 34.5134 - accuracy: 0.5435 - val_loss: 25.8554 - val_accuracy: 0.5696
# Epoch 4/50
# 23/23 [==============================] - 0s 3ms/step - loss: 21.6352 - accuracy: 0.5261 - val_loss: 14.4271 - val_accuracy: 0.6522
# Epoch 5/50
# 23/23 [==============================] - 0s 3ms/step - loss: 12.9047 - accuracy: 0.7087 - val_loss: 9.4440 - val_accuracy: 0.6870
# Epoch 6/50
# 23/23 [==============================] - 0s 3ms/step - loss: 9.2968 - accuracy: 0.7652 - val_loss: 6.8141 - val_accuracy: 0.7783
# Epoch 7/50
# 23/23 [==============================] - 0s 3ms/step - loss: 6.8303 - accuracy: 0.7870 - val_loss: 4.9515 - val_accuracy: 0.7652
# Epoch 8/50
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1234 - accuracy: 0.8130 - val_loss: 3.8508 - val_accuracy: 0.8174
# Epoch 9/50
# 23/23 [==============================] - 0s 2ms/step - loss: 3.8315 - accuracy: 0.8304 - val_loss: 2.9701 - val_accuracy: 0.8261
# Epoch 10/50
# 23/23 [==============================] - 0s 2ms/step - loss: 3.1207 - accuracy: 0.8565 - val_loss: 2.4207 - val_accuracy: 0.8609
# Epoch 11/50
# 23/23 [==============================] - 0s 2ms/step - loss: 2.5277 - accuracy: 0.8783 - val_loss: 2.0442 - val_accuracy: 0.9217
# Epoch 12/50
# 23/23 [==============================] - 0s 2ms/step - loss: 2.1449 - accuracy: 0.8870 - val_loss: 1.8806 - val_accuracy: 0.9348
# Epoch 13/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1.8436 - accuracy: 0.9217 - val_loss: 1.6738 - val_accuracy: 0.9391
# Epoch 14/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1.5942 - accuracy: 0.9261 - val_loss: 1.5975 - val_accuracy: 0.9435
# Epoch 15/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1.4919 - accuracy: 0.9348 - val_loss: 1.4383 - val_accuracy: 0.9565
# Epoch 16/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1.3537 - accuracy: 0.9435 - val_loss: 1.3252 - val_accuracy: 0.9565
# Epoch 17/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1.2635 - accuracy: 0.9478 - val_loss: 1.2697 - val_accuracy: 0.9565
# Epoch 18/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1.2119 - accuracy: 0.9522 - val_loss: 1.2492 - val_accuracy: 0.9565
# Epoch 19/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1.1505 - accuracy: 0.9565 - val_loss: 1.2111 - val_accuracy: 0.9565
# Epoch 20/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1.1033 - accuracy: 0.9522 - val_loss: 1.0986 - val_accuracy: 0.9652
# Epoch 21/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1.0217 - accuracy: 0.9565 - val_loss: 1.0955 - val_accuracy: 0.9652
# Epoch 22/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.9961 - accuracy: 0.9565 - val_loss: 0.9769 - val_accuracy: 0.9652
# Epoch 23/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.9282 - accuracy: 0.9609 - val_loss: 0.9208 - val_accuracy: 0.9652
# Epoch 24/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.8766 - accuracy: 0.9609 - val_loss: 1.0179 - val_accuracy: 0.9652
# Epoch 25/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.9355 - accuracy: 0.9609 - val_loss: 0.8671 - val_accuracy: 0.9652
# Epoch 26/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7624 - accuracy: 0.9609 - val_loss: 0.7777 - val_accuracy: 0.9696
# Epoch 27/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7124 - accuracy: 0.9565 - val_loss: 0.7416 - val_accuracy: 0.9696
# Epoch 28/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6920 - accuracy: 0.9609 - val_loss: 0.6721 - val_accuracy: 0.9696
# Epoch 29/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6487 - accuracy: 0.9696 - val_loss: 0.6653 - val_accuracy: 0.9739
# Epoch 30/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5548 - accuracy: 0.9696 - val_loss: 0.5795 - val_accuracy: 0.9739
# Epoch 31/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.5084 - accuracy: 0.9783 - val_loss: 0.5279 - val_accuracy: 0.9739
# Epoch 32/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4803 - accuracy: 0.9783 - val_loss: 0.4985 - val_accuracy: 0.9739
# Epoch 33/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4435 - accuracy: 0.9783 - val_loss: 0.4825 - val_accuracy: 0.9739
# Epoch 34/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4345 - accuracy: 0.9783 - val_loss: 0.4774 - val_accuracy: 0.9783
# Epoch 35/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4050 - accuracy: 0.9826 - val_loss: 0.4129 - val_accuracy: 0.9783
# Epoch 36/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3412 - accuracy: 0.9870 - val_loss: 0.3844 - val_accuracy: 0.9783
# Epoch 37/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.3242 - accuracy: 0.9870 - val_loss: 0.4162 - val_accuracy: 0.9783
# Epoch 38/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3085 - accuracy: 0.9870 - val_loss: 0.3941 - val_accuracy: 0.9783
# Epoch 39/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.3160 - accuracy: 0.9870 - val_loss: 0.3666 - val_accuracy: 0.9783
# Epoch 40/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.3051 - accuracy: 0.9826 - val_loss: 0.3477 - val_accuracy: 0.9739
# Epoch 41/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2870 - accuracy: 0.9870 - val_loss: 0.3393 - val_accuracy: 0.9739
# Epoch 42/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2687 - accuracy: 0.9870 - val_loss: 0.3384 - val_accuracy: 0.9783
# Epoch 43/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2810 - accuracy: 0.9870 - val_loss: 0.3275 - val_accuracy: 0.9783
# Epoch 44/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2603 - accuracy: 0.9870 - val_loss: 0.3245 - val_accuracy: 0.9783
# Epoch 45/50
# 23/23 [==============================] - 0s 3ms/step - loss: 0.2556 - accuracy: 0.9826 - val_loss: 0.3128 - val_accuracy: 0.9783
# Epoch 46/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2527 - accuracy: 0.9826 - val_loss: 0.2956 - val_accuracy: 0.9783
# Epoch 47/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2435 - accuracy: 0.9826 - val_loss: 0.2924 - val_accuracy: 0.9783
# Epoch 48/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2521 - accuracy: 0.9870 - val_loss: 0.3020 - val_accuracy: 0.9783
# Epoch 49/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2362 - accuracy: 0.9783 - val_loss: 0.2842 - val_accuracy: 0.9783
# Epoch 50/50
# 23/23 [==============================] - 0s 2ms/step - loss: 0.2380 - accuracy: 0.9826 - val_loss: 0.2759 - val_accuracy: 0.9739
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2116 - accuracy: 0.9870
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2759 - accuracy: 0.9739
# Training Accuracy: 98.70%
# Test Accuracy: 97.39%
# Layer 1 - Weights:
#  [[ 0.35389745 -0.45232597  0.37826696  0.21769272  0.39160725 -0.45236084]
#  [ 0.6423984   0.05204511 -0.7224503  -0.17898954  0.6109324   0.57208115]
#  [ 0.1032315  -0.10152984  0.0370501  -0.25715503  0.40215737 -0.85845613]
#  [ 0.29722565 -0.52282834  0.57384413  0.47153986  0.1213562  -0.6840615 ]]
#
# Layer 1 - Biases:
#  [-0.02581114  0.         -0.07533294  0.08779834  0.01931965 -0.16170777]
#
# Layer 2 - Weights:
#  [[-0.37768576  0.6574277   0.48583966 -0.11043026  0.48702452]
#  [ 0.3552279   0.31469005 -0.5380177  -0.2906212   0.65133494]
#  [ 0.607823   -0.34204355  0.59971195  0.14811075 -0.48784035]
#  [-0.5129887   0.16697042  0.09235597  0.33516854  0.16858944]
#  [ 0.6916288  -0.43456817  0.3362361   0.7766684  -0.17177376]
#  [-0.61757845 -0.2231157   0.14816105 -0.1073058   0.53002155]]
#
# Layer 2 - Biases:
#  [-0.07629374 -0.01250899  0.07762778  0.1600816  -0.07746001]
#
# Layer 3 - Weights:
#  [[ 0.4353519   0.6385339  -0.50364405]
#  [ 0.08641313 -0.81357306 -0.52269363]
#  [-0.36146486 -0.24557889  0.19623725]
#  [ 0.23880467 -0.17275223  0.04005193]
#  [-0.45516354  0.645756    0.32284704]]
#
# Layer 3 - Biases:
#  [ 0.10204481 -0.11339837  0.26748317]
# 1/1 [==============================] - 0s 36ms/step
# [[3.0441553e-05 1.0000000e+00 3.7215829e-03]]

# %%
intermediate_layer_model = Model(inputs=model.input, outputs=model.get_layer(index=2).output)
input_data = tf.constant([[905,120,768,854]]) # Örnek girdi verisi
intermediate_output = intermediate_layer_model.predict(input_data)
print(intermediate_output)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# [[1.0000000e+00 3.3881233e-22 1.7318629e-16]]
