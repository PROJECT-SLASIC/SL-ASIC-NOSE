# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
# 1. Manually define weights and biases
# For the sake of demonstration, I'm initializing weights and biases with random values. 
# You'll replace these with the actual values you have.

# Layer 1: 6 neurons, input dimension = 4




# 2. Build the neural network
model = Sequential()
model.add(Dense(15, input_dim=5, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(6, activation=None))  # No activation to get logits


import numpy as np

weights_layer1 = np.array([
    [-0.09818033,  1.3192399,  -0.09481156,  0.7905624,   3.0558255,  -2.4061432,   0.01573166, -0.26245388, -0.3832402,  -0.2618663,  -0.5675667,   0.20460761, -0.15860777,  0.3293453,  -0.3184814 ],
    [ 0.36039242,  1.3836999,  -0.38076693, -0.15627399,  1.242816,   -0.8726576,   0.56904596, -0.31569335,  0.2573816,  -0.1549069,   0.6274383,  -0.43695807, -0.3122815,  -0.39576316, -0.51869553],
    [-0.9052477,   0.5380823,   0.3054285,   1.4171979,   0.33256674, -2.0450497,  -1.351918,    0.4145339,   0.00142722,  0.36755317, -1.1603684,   0.48782676,  0.03056485, -0.52732396, -0.20308313],
    [-0.51942396,  0.88335484,  0.3957228,   0.22865102,  0.8137816,  -1.9638786,  -0.30486897, -0.19186738,  0.14666386, -0.16989386,  0.8327772,  -0.5496546,  -0.45072916,  0.06473535,  0.4126495 ],
    [-0.44560996,  0.38872883, -0.4510312,   1.0372542,   0.53571314, -1.686427,    0.22401616,  0.06663352, -0.40427768,  0.00995948, -0.1126792,   0.34445775,  0.543891,    0.1803309,  -0.00390732]
])

biases_layer1 = np.array([
    0.78905904, 0.5784754, 0., -0.20275837, -0.40283212, 1.1644777, 0.35123855, -0.00514247, -0.01699449, -0.00515357, 0.19779488, -0.03612271, -0.00515211, -0.00514015, 0.
])



weights_layer2 = np.array([
    [ 0.6434228,   0.0003404,  -0.5290125,   1.1466728,   0.99855197,  1.4451936,   0.49197364,  0.3435211 ],
    [ 0.96217734, -0.4402995,   1.2904841,  -0.15714349, -0.00215536,  0.23692982, -0.63084966, -0.0425845 ],
    [ 0.17361659, -0.31190532, -0.29012898,  0.20873988, -0.09161609, -0.41182122, -0.38325128, -0.08431214],
    [-1.0502908,  -0.00654846,  1.2904577,  -2.3002045,  -0.69328046, -1.7623827,  -1.2010212,   1.2286621 ],
    [-0.51792115, -0.49287945,  1.8640902,  -2.3597658,   0.37595606,  0.02846978, -2.8566062,  -0.24675947],
    [-2.4447293,  -0.07684483, -1.4551891,   3.1861305,   1.7849959,   1.2227705,   2.1000974,   1.7133521 ],
    [ 0.9647257,   0.4433147,  -1.0299988,   0.5873994,   1.0982528,   1.0883551,   0.18280058, -1.8084152 ],
    [ 0.15433586, -0.34015927, -0.41403213,  0.0682138,  -0.328536,   -0.0047945,  -0.43431553,  0.18701088],
    [-0.38463643,  0.25469774,  0.07524145, -0.10185216, -0.04764435,  0.11614972, -0.4232087,  -0.48785424],
    [ 0.3075872,  -0.45146912, -0.07743012,  0.21495724, -0.42873508, -0.37985373, -0.4111169,  -0.30266547],
    [ 1.7479831,   0.34688655, -0.26741952,  0.62883383,  0.61427593, -0.10042682, -0.40109333, -1.5508428 ],
    [-0.328197,    0.19894081, -0.4661376,  -0.18982759, -0.45209208,  0.2573719,   0.12480965, -0.10319609],
    [-0.40909338,  0.13356954,  0.43743497, -0.28761497, -0.44502628, -0.0139634,  -0.09590751,  0.28957713],
    [ 0.34301007,  0.17965657, -0.07589861,  0.13389748, -0.45219308, -0.0641695,  -0.30853683,  0.27437127],
    [-0.39954722,  0.49915904,  0.11819649,  0.42383903,  0.49642032, -0.47704428, -0.15251401,  0.41101617]
])

biases_layer2 = np.array([
    0.6270914, -0.01611324, 0.0361886, 0.36470598, 0.07628674, 0.4092654, 0.29593942, 0.4188261
])


weights_layer3 = np.array([
    [-1.7644453,   0.99012446, -0.06824843,  1.7002444,   0.39561418, -2.2487998],
    [-0.23652393,  0.03554043,  0.4067599,  -0.23138107, -0.46645096, -0.07222383],
    [ 1.0420333,  -1.6086143,  -1.0809544,   0.1804224,   0.85051626, -0.60671335],
    [-0.7058884,   1.131019,    0.6499093,  -2.1210449,  -1.7778326,   0.6596131],
    [-1.9632035,   0.28023675,  0.85509956, -0.1131083,   1.0656755,   0.8827117],
    [-0.75987256, -0.0443735,   1.0485371,  -0.14812693, -3.002738,    0.10270439],
    [ 0.04535875,  1.564129,   -2.9903226,  -1.2822828,  -0.32779527,  2.382335],
    [ 1.833578,   -0.50584924, -2.1277294,  -1.063904,   -2.7688127,   1.7635028]
])


biases_layer3 = np.array([0.02719244, 0.20696507, -0.39281777, 0.14795905, 0.36482835, -0.45234653])



# 3. Set weights and biases manually
model.layers[0].set_weights([weights_layer1, biases_layer1])
model.layers[1].set_weights([weights_layer2, biases_layer2])
model.layers[2].set_weights([weights_layer3, biases_layer3])


# 4. Get the output (logits) for some input data
# For demonstration purposes, I'm using a random input. Replace with your actual input data.

sample_input = np.array([[0.02829,0.1370477,0.0453447,0.135227,0.099465]])  # Example input data
logits_output = model.predict(sample_input)

print(logits_output)
# Out:
# 1/1 [==============================] - 0s 36ms/step
# [[-10.7084055   6.701612    2.837421   -4.563235  -10.080672    1.8478007]]
